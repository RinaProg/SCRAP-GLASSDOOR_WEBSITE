# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
url='https://www.glassdoor.co.in/Explore/browse-companies.html?'
webpage=requests.get(url,headers=headers).text

# %%
soup=BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" style="height: 100%;" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
#  <head>
#   <link href="/explore/static/css/gd-companyExplorer.55acb.css" media="all" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="#0caa41" name="theme-color"/>
#   <meta content="#0caa41" name="msapplication-navbutton-color"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="0" http-equiv="Expires"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://www.facebook.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://cdnjs.cloudflare.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/>
#   <link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6uyw4BMUTPHjx4wXiWtFCc.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2" rel="preload" type="font/woff2"/>
#   <link href="/garnish/static/css/gd-core.bundle.45ef8.css" rel="stylesheet"/>
#   <link href="/garnish/static/css/gd-footer.bundle.f1857.css" rel="stylesheet"/>
#   <link href="/garnish/static/css/gd-siteHeader.bundle.a3de5.css" rel="stylesheet"/>
#   <link href="/garnish/static/css/gd-user-login-one-tap.bundle.css?v=26089" rel="stylesheet"/>
#   <title data-rh="true">
#    Browse Companies | Glassdoor
#   </title>
#   <meta content="Browse Companies" data-rh="true" property="og:title"/>
#   <meta content="Browse Companies. Salaries, reviews, and more - all posted by employees. Apply to jobs near you." data-rh="true" name="description"/>
#   <meta content="Browse Companies. Salaries, reviews, and more - all posted by employees. Apply to jobs near you." data-rh="true" property="og:description"/>
#   <meta content="https://www.glassdoor.com/explore/static/images/brand-campaign-image.png" data-rh="true" property="og:image"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.co.in/Explore/browse-companies.htm" rel="canonical"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.at/Entdecken/unternehmen-entdecken.htm" hreflang="de-AT" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://de.glassdoor.ch/Entdecken/unternehmen-entdecken.htm" hreflang="de-CH" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.de/Entdecken/unternehmen-entdecken.htm" hreflang="de-DE" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com.au/Explore/browse-companies.htm" hreflang="en-AU" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.ca/Explore/browse-companies.htm" hreflang="en-CA" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.co.uk/Explore/browse-companies.htm" hreflang="en-GB" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com.hk/Explore/browse-companies.htm" hreflang="en-HK" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.ie/Explore/browse-companies.htm" hreflang="en-IE" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.co.in/Explore/browse-companies.htm" hreflang="en-IN" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.co.nz/Explore/browse-companies.htm" hreflang="en-NZ" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.sg/Explore/browse-companies.htm" hreflang="en-SG" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com/Explore/browse-companies.htm" hreflang="en-US" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com.ar/Explorar/buscar-empresas.htm" hreflang="es-AR" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.es/Explorar/buscar-empresas.htm" hreflang="es-ES" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com.mx/Explorar/buscar-empresas.htm" hreflang="es-MX" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://fr.glassdoor.be/Decouvrir/parcourir-les-entreprises.htm" hreflang="fr-BE" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://fr.glassdoor.ca/Decouvrir/parcourir-les-entreprises.htm" hreflang="fr-CA" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://fr.glassdoor.ch/Decouvrir/parcourir-les-entreprises.htm" hreflang="fr-CH" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.fr/Decouvrir/parcourir-les-entreprises.htm" hreflang="fr-FR" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.it/Cerca/cerca-aziende.htm" hreflang="it-IT" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://nl.glassdoor.be/Ontdekken/bedrijven-zoeken.htm" hreflang="nl-BE" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.nl/Ontdekken/bedrijven-zoeken.htm" hreflang="nl-NL" rel="alternate"/>
#   <link data-rh="true" datarh="true" href="https://www.glassdoor.com.br/Explorar/pesquisar-empresas.htm" hreflang="pt-BR" rel="alternate"/>
#  </head>
#  <body class="main lang-en en-IN gdGrid" data-locale="en-IN" marginheight="0" marginwidth="0">
#   <div id="UserAlert">
#   </div>
#   <header id="SiteNav">
#    <nav class="d-flex align-items-center siteHeader__HeaderStyles__navigationBackground siteHeader__HeaderStyles__relativePosition" data-test="background-header-nav">
#     <div class="col siteHeader__HeaderStyles__bottomShadow">
#      <div class="siteHeader__HeaderStyles__navigationWrapper">
#       <div class="d-flex justify-content-between align-items-center px-std px-md-lg siteHeader__HeaderStyles__mainNav">
#        <div class="d-lg-none" id="SignInButton">
#         <button class="d-flex align-items-center justify-content-center p-0 m-0 siteHeader__HeaderStyles__signInButton" type="button">
#          Sign In
#         </button>
#        </div>
#        <div class="siteHeader__HeaderStyles__brandLogoContainer">
#         <a alt="" aria-label="Glassdoor Logo" data-test="header-glassdoor-logo" href="/index.htm" rel="nofollow" target="_top">
#          <span class="SVGInline d-flex align-items-center siteHeader__HeaderStyles__brandLogo">
#           <svg class="SVGInline-svg d-flex-svg align-items-center-svg siteHeader__HeaderStyles__brandLogo-svg" height="24" viewbox="0 0 163 32" width="122" xmlns="http://www.w3.org/2000/svg">
#            <path d="M163 7.366a.55.55 0 00-.285-.447c-.37-.182-.908-.307-2.005-.307-2.475 0-4.664 1.211-5.619 3.237V7.374a.39.39 0 00-.393-.388h-3.706a.39.39 0 00-.393.388v16.684a.39.39 0 00.393.388h3.882a.391.391 0 00.394-.388v-7.505c0-3.352 2.366-5.018 5.442-5.018a6.37 6.37 0 011.794.274c.246.08.496-.12.496-.376V7.366zm-24.807 12.986c-2.653 0-4.705-1.85-4.705-4.644s2.053-4.645 4.705-4.645c2.653 0 4.704 1.852 4.704 4.645 0 2.794-2.051 4.644-4.704 4.644zm0-13.794c-5.447 0-9.515 3.702-9.515 9.15s4.068 9.15 9.515 9.15c5.446 0 9.514-3.702 9.514-9.15s-4.068-9.15-9.514-9.15zm-21.6 13.794c-2.653 0-4.705-1.85-4.705-4.644 0-2.793 2.052-4.644 4.705-4.644s4.704 1.85 4.704 4.644-2.051 4.644-4.704 4.644zm0-13.794c-5.447 0-9.515 3.702-9.515 9.15s4.068 9.15 9.515 9.15c5.446 0 9.514-3.702 9.514-9.15s-4.068-9.15-9.514-9.15zm-21.57 13.837c-2.652 0-4.633-1.85-4.633-4.68 0-2.828 1.981-4.68 4.634-4.68 2.618 0 4.633 1.782 4.633 4.68 0 2.864-2.015 4.68-4.633 4.68zM103.792.001H99.91a.39.39 0 00-.392.388V9.5c-1.203-1.676-3.184-2.969-5.943-2.969-4.315 0-7.994 3.284-7.994 9.186 0 5.901 3.68 9.183 8.064 9.183 2.583 0 4.6-1.117 5.872-2.898v2.057a.39.39 0 00.393.388h3.882a.39.39 0 00.393-.388V.39a.39.39 0 00-.393-.389zM83.01 19.161c0 3.981-2.936 5.693-7.64 5.693-3.249 0-6.044-.864-7.643-2.651a.395.395 0 01-.01-.504l2.244-2.877a.39.39 0 01.589-.022c1.187 1.199 3.01 1.932 5.28 1.932 1.309 0 2.37-.348 2.37-1.326 0-.944-.955-1.152-3.926-1.781-2.618-.525-5.872-1.711-5.872-5.518 0-3.527 2.83-5.553 7.464-5.553 3.047 0 5.238.908 6.783 2.338a.39.39 0 01.037.526l-2.13 2.73a.386.386 0 01-.558.06c-1.045-.92-2.78-1.498-4.486-1.498-1.45 0-2.264.455-2.264 1.223 0 .873.956 1.083 4.104 1.746 3.076.663 5.658 1.816 5.658 5.482zm-17.952.01c0 3.981-2.936 5.693-7.64 5.693-3.249 0-6.044-.864-7.643-2.651a.395.395 0 01-.01-.503l2.244-2.878a.391.391 0 01.589-.022c1.187 1.2 3.01 1.933 5.28 1.933 1.309 0 2.37-.349 2.37-1.327 0-.944-.955-1.152-3.926-1.781-2.618-.524-5.872-1.711-5.872-5.518 0-3.527 2.83-5.552 7.464-5.552 3.046 0 5.237.908 6.782 2.337a.39.39 0 01.037.526l-2.13 2.73a.386.386 0 01-.557.061c-1.045-.92-2.78-1.5-4.487-1.5-1.45 0-2.264.456-2.264 1.224 0 .873.957 1.083 4.104 1.746 3.076.663 5.659 1.816 5.659 5.482zm-23.268-1.78c0 1.92-1.59 3.597-4.067 3.597-1.627 0-2.512-.734-2.512-1.851 0-.978.744-1.712 2.194-1.922l4.385-.523v.699zM38.713 6.6c-3.704 0-6.495 1.224-7.742 3.643a.392.392 0 00.129.495l2.83 1.996c.178.125.428.084.535-.105.786-1.397 2.547-1.874 4.248-1.874 2.087 0 3.076.732 3.076 1.746v.279c0 .42-.247.63-.919.699l-4.846.419c-3.254.313-5.658 2.304-5.658 5.482 0 3.213 2.475 5.448 5.977 5.448 2.759 0 4.527-1.327 5.446-2.724v1.987a.39.39 0 00.393.388h3.883a.39.39 0 00.393-.388V13.689c0-4.854-2.582-7.089-7.745-7.089zM27.163.387v23.668a.39.39 0 01-.393.389h-3.918a.39.39 0 01-.393-.389V.38c0-.21.173-.38.385-.38h3.926a.39.39 0 01.393.388zm-17.72 19.99c-2.652 0-4.633-1.851-4.633-4.68 0-2.829 1.98-4.68 4.633-4.68s4.598 1.782 4.598 4.68c0 2.863-1.945 4.68-4.598 4.68zm8.768-13.41h-3.878a.396.396 0 00-.398.393v2.052c-.99-1.572-3.042-2.864-5.765-2.864-4.386 0-8.17 3.248-8.17 9.08C0 21.424 3.607 24.6 8.311 24.6c2.547 0 4.527-1.047 5.695-2.688v1.117c0 2.514-1.239 4.505-5.2 4.505-1.991 0-3.59-.654-4.992-1.88a.388.388 0 00-.59.082l-1.759 2.91c-.227.376-.196.587-.052.711 1.806 1.55 4.155 2.507 7.57 2.507 7.428 0 9.621-4.085 9.621-8.59V7.355a.39.39 0 00-.393-.388z" fill="#0CAA41" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </div>
#        <div class="d-flex col justify-content-end" id="SearchForm">
#         <div class="d-flex d-lg-none pr-std">
#          <button aria-label="Search Form" class="p-0 search__SearchStyles__iconBtn" data-test="icon-search-menu-open-trigger" title="Open Search Form" type="button">
#           <span class="SVGInline d-flex search__SearchStyles__colorDefault">
#            <svg class="SVGInline-svg d-flex-svg search__SearchStyles__colorDefault-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#          </button>
#         </div>
#         <div class="d-none d-lg-flex col px-xxl py-std">
#          <form action="/Reviews/company-reviews.htm" class="col search__SearchStyles__searchForm" data-test="search-bar-form" id="scBar" method="GET" novalidate="" target="_top">
#           <div class="d-flex flex-row align-items-center">
#            <input name="suggestCount" type="hidden" value="0"/>
#            <input name="suggestChosen" type="hidden" value="false"/>
#            <input name="clickSource" type="hidden" value="searchBtn"/>
#            <input name="typedKeyword" type="hidden" value=""/>
#            <input name="typedLocation" type="hidden" value=""/>
#            <input name="locT" type="hidden" value=""/>
#            <input name="locId" type="hidden" value=""/>
#            <input name="jobType" type="hidden" value=""/>
#            <input name="context" type="hidden" value="Review"/>
#            <div class="d-flex col-6 p-0 search__SearchStyles__searchKeywordContainer">
#             <span class="d-flex align-items-center search__SearchStyles__searchInputLabel">
#              <span class="SVGInline d-flex search__SearchStyles__searchIcon">
#               <svg class="SVGInline-svg d-flex-svg search__SearchStyles__searchIcon-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#             </span>
#             <style data-emotion="css 1fttcpj">
#              .css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
#             </style>
#             <div class="col headerSearchInput css-1fttcpj ew8s0qn1">
#              <style data-emotion="css 1q3ssei">
#               .css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-ms-flex-pack:space-around;-webkit-justify-content:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}
#              </style>
#              <div class="input-wrapper css-1q3ssei e1h5k8h92">
#               <style data-emotion="css eyudwk">
#                .css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}
#               </style>
#               <input aria-label="Search Keyword" class="css-eyudwk e1h5k8h90" data-test="search-bar-keyword-input" id="sc.keyword" name="sc.keyword" placeholder="Company Name" type="text" value=""/>
#              </div>
#             </div>
#            </div>
#            <style data-emotion="css 1fttcpj">
#             .css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
#            </style>
#            <div class="ml-xsm search__SearchStyles__searchDropdown css-1fttcpj ew8s0qn1">
#             <select aria-label="Search Context Picker" data-test="search-bar-context-picker" name="dropdown" style="display:none">
#              <option value="0">
#              </option>
#              <option checked="" selected="" value="1">
#              </option>
#              <option value="2">
#              </option>
#              <option value="3">
#              </option>
#             </select>
#             <style data-emotion="css 1rbr22t">
#              .css-1rbr22t{font-size:15px;background-color:#fff;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;color:#858c94;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-1rbr22t:hover{border-color:#858c94;color:#505863;}.css-1rbr22t::-webkit-input-placeholder{color:#c4c7cc;}.css-1rbr22t::-moz-placeholder{color:#c4c7cc;}.css-1rbr22t:-ms-input-placeholder{color:#c4c7cc;}.css-1rbr22t::placeholder{color:#c4c7cc;}.css-1rbr22t:focus,.css-1rbr22t:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;color:#505863;}.css-1rbr22t.css-1rbr22t{height:40px;line-height:40px;cursor:pointer;color:#505863;}.css-1rbr22t .arrowDown,.css-1rbr22t .arrowUp{position:absolute;right:14px;top:0px;cursor:pointer;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-1rbr22t .arrowDown svg,.css-1rbr22t .arrowUp svg{height:16px;width:16px;}.css-1rbr22t .arrowDown svg #prefix__icon-carot-down-1,.css-1rbr22t .arrowUp svg #prefix__icon-carot-down-1{fill:currentColor;}.css-1rbr22t .arrowUp svg{-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.css-1rbr22t .dropdownOptions{position:absolute;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;top:calc(100% + 8px);left:-1px;background:white;border-radius:3px;border:solid 1px #c4c7cc;min-width:100%;padding:0px;margin:0px;z-index:999;overflow:auto;width:204px;}.css-1rbr22t .dropdownOptions.above{top:auto;bottom:calc(100% + 8px);}.css-1rbr22t .dropdownOptions.right{left:auto;right:-1px;}.css-1rbr22t .dropDownOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.css-1rbr22t .scrollBar{-webkit-flex:1;-ms-flex:1;flex:1;padding-left:4px;padding-right:4px;height:100%;background:#fff;min-width:8px;box-sizing:content-box;}.css-1rbr22t .scrollThumb{width:8px;background:#c4c7cc;border-radius:8px;cursor:default;}.css-1rbr22t .dropdownOptions ul{padding:0px;margin:0px;overflow:auto;max-height:200px;scrollbar-width:none;-ms-overflow-style:none;width:100%;}.css-1rbr22t .dropdownOptions ul::-webkit-scrollbar{width:0;height:0;}@-webkit-keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}@keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}.css-1rbr22t .dropdownExpanded{display:block;-webkit-animation-name:expandDropDown;animation-name:expandDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0, 0, 0.38, 0.9);animation-timing-function:cubic-bezier(0, 0, 0.38, 0.9);overflow:hidden;max-height:201.6px;box-shadow:0px 0px 2px #c4c7cc;}@-webkit-keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}@keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}.css-1rbr22t .dropdownCollapsed.animated{border:none;overflow:hidden;max-height:0;-webkit-animation-name:collapseDropDown;animation-name:collapseDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0.2, 0, 0.38, 0.9);animation-timing-function:cubic-bezier(0.2, 0, 0.38, 0.9);}.css-1rbr22t .dropdownCollapsed{border:none;overflow:hidden;max-height:0;}.css-1rbr22t .dropdownOptions li.dropdownOption{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;list-style:none;width:100%;cursor:pointer;height:40px;line-height:normal;min-width:100%;}.css-1rbr22t .dropdownOptions li.dropdownOption.hovered{background:#dee0e3;}.css-1rbr22t div.selectedLabel{m ...
#             </style>
#             <div aria-activedescendant="option_1_0087400-7c-e42-c415-efa5e7ee4655" aria-expanded="false" aria-label="Search Context Picker" class="css-1rbr22t egu3u860" data-test="search-bar-context-pickerContent" direction="auto" role="listbox" selected="" style="width:132px" tabindex="0">
#              <div class="selectedLabel">
#               Companies
#               <span alt="" class="SVGInline arrowDown">
#                <svg class="SVGInline-svg arrowDown-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#              <div class="dropdownOptions dropdownCollapsed">
#               <div class="dropDownOptionsContainer">
#                <ul>
#                 <li aria-selected="false" class="dropdownOption" id="option_0" role="option">
#                  <div class="checkmark">
#                   <span alt="" class="SVGInline">
#                    <svg class="SVGInline-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd">
#                     </path>
#                    </svg>
#                   </span>
#                  </div>
#                  <span class="dropdownOptionLabel">
#                   Jobs
#                  </span>
#                 </li>
#                 <li aria-selected="true" class="dropdownOption checked" id="option_1" role="option">
#                  <div class="checkmark">
#                   <span alt="" class="SVGInline">
#                    <svg class="SVGInline-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd">
#                     </path>
#                    </svg>
#                   </span>
#                  </div>
#                  <span class="dropdownOptionLabel">
#                   Companies
#                  </span>
#                 </li>
#                 <li aria-selected="false" class="dropdownOption" id="option_2" role="option">
#                  <div class="checkmark">
#                   <span alt="" class="SVGInline">
#                    <svg class="SVGInline-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd">
#                     </path>
#                    </svg>
#                   </span>
#                  </div>
#                  <span class="dropdownOptionLabel">
#                   Salaries
#                  </span>
#                 </li>
#                 <li aria-selected="false" class="dropdownOption" id="option_3" role="option">
#                  <div class="checkmark">
#                   <span alt="" class="SVGInline">
#                    <svg class="SVGInline-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                     <path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd">
#                     </path>
#                    </svg>
#                   </span>
#                  </div>
#                  <span class="dropdownOptionLabel">
#                   Interviews
#                  </span>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#            <style data-emotion="css 1fttcpj">
#             .css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
#            </style>
#            <div class="ml-xsm col-4 p-0 headerSearchInput search__SearchStyles__searchBarLocationInput css-1fttcpj ew8s0qn1">
#             <style data-emotion="css 1q3ssei">
#              .css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-ms-flex-pack:space-around;-webkit-justify-content:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}
#             </style>
#             <div class="input-wrapper css-1q3ssei e1h5k8h92">
#              <style data-emotion="css eyudwk">
#               .css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}
#              </style>
#              <input aria-label="Search Location" class="css-eyudwk e1h5k8h90" data-test="search-bar-location-input" id="sc.location" placeholder="Location" type="text" value=""/>
#             </div>
#            </div>
#            <style data-emotion="css 1sojqiq">
#             .css-1sojqiq{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:#0caa41;color:#fff;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1sojqiqa[href]:link,.css-1sojqiqa[href]:visited{color:#fff;}.css-1sojqiq:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1sojqiq:focus{outline:0;}.css-1sojqiq:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1sojqiq:hover{background-color:#056b27;color:#fff;}}.css-1sojqiq[disabled]{background-color:#a4ebbc;cursor:not-allowed;}
#            </style>
#            <button class="gd-ui-button ml-std col-auto search__SearchStyles__newSearchButton css-1sojqiq evpplnh1" data-test="search-bar-submit" type="submit">
#             <style data-emotion="css 2etp8b">
#              .css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}
#             </style>
#             <span class="css-2etp8b evpplnh0">
#              <span>
#               Search
#              </span>
#             </span>
#            </button>
#           </div>
#          </form>
#         </div>
#         <div>
#         </div>
#        </div>
#        <div class="d-flex d-lg-none" id="HamburgerButton">
#         <button aria-label="Navigation Menu" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Open Navigation Menu" type="button">
#          <span class="SVGInline d-flex icon__IconStyles__colorDefault">
#           <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <g fill="currentColor" fill-rule="evenodd">
#             <path d="M21 11H3a1 1 0 000 2h18a1 1 0 000-2zM3 5h18a1 1 0 000-2H3a1 1 0 000 2zM21 19H3a1 1 0 000 2h18a1 1 0 000-2z">
#             </path>
#            </g>
#           </svg>
#          </span>
#         </button>
#         <div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation">
#          <div>
#           <div class="col">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader">
#             <div class="col">
#              <div class="d-flex flex-row">
#              </div>
#             </div>
#             <div>
#              <div class="d-flex flex-row">
#               <button aria-label="Close navigation menu" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" type="button">
#                <span class="SVGInline d-flex icon__IconStyles__colorNavigation">
#                 <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="col siteHeader__HeaderStyles__bottomShadow">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left">
#             <div class="d-flex">
#              <div class="siteHeader__HeaderStyles__h1">
#               Explore
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto">
#           <ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu">
#            <li class="p-0 m-0">
#             <div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header jobs" data-ga-lbl="null" data-test="site-header-jobs" href="/Job/jobsHomeRedirect.htm" rel="" tabindex="0" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M16 4H8a1 1 0 00-1 1v1h10V5a1 1 0 00-1-1zm-1.5 10a.5.5 0 01.09 1H9.5a.5.5 0 010-1zM20 7H4a1 1 0 00-1 1v6a1 1 0 001 1h3.28l.5 2h8.44l.5-2H20a1 1 0 001-1V8a1 1 0 00-1-1zM6.5 16H4v3a1 1 0 001 1h14a1 1 0 001-1v-3h-2.5l-.5 2H7zM16 3a2 2 0 012 2v1h2a2 2 0 012 2v6a2 2 0 01-1 1.73V19a2 2 0 01-2 2H5a2 2 0 01-2-2v-3.27A2 2 0 012 14V8a2 2 0 012-2h2V5a2 2 0 012-2z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Jobs
#                </span>
#               </span>
#               <span class="SVGInline d-flex ml-sm mr-std icon__IconStyles__colorNavigation">
#                <svg class="SVGInline-svg d-flex-svg ml-sm-svg mr-std-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#             </div>
#            </li>
#            <li class="p-0 m-0">
#             <div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header companies" data-ga-lbl="null" data-test="site-header-companies" href="/Reviews/index.htm" rel="" tabindex="0" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M13.5 6.5a.5.5 0 01.5.5v1a.5.5 0 01-.5.5h-1A.5.5 0 0112 8V7a.5.5 0 01.5-.5zm4 0a.5.5 0 01.5.5v1a.5.5 0 01-.5.5h-1A.5.5 0 0116 8V7a.5.5 0 01.5-.5zm-4 4a.5.5 0 01.5.5v1a.5.5 0 01-.5.5h-1a.5.5 0 01-.5-.5v-1a.5.5 0 01.5-.5zm4 0a.5.5 0 01.5.5v1a.5.5 0 01-.5.5h-1a.5.5 0 01-.5-.5v-1a.5.5 0 01.5-.5zm-1 5h-3a.49.49 0 00-.5.5v3.5h4V16a.5.5 0 00-.5-.5zm4-11h-11A.5.5 0 009 5v14.5h3v-4a1 1 0 011-1h4a1 1 0 011 1v4h3V5a.5.5 0 00-.5-.5zm.5-1a1 1 0 011 1v16H8v-16a1 1 0 011-1zm-15 5v1H3.5a.5.5 0 00-.5.5v9.5h3v1H2v-11a.91.91 0 01.78-1z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Companies
#                </span>
#               </span>
#               <span class="SVGInline d-flex ml-sm mr-std icon__IconStyles__colorNavigation">
#                <svg class="SVGInline-svg d-flex-svg ml-sm-svg mr-std-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#             </div>
#            </li>
#            <li class="p-0 m-0">
#             <div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header salaries" data-ga-lbl="null" data-test="site-header-salaries" href="/Salaries/index.htm" rel="" tabindex="0" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M12 9a2 2 0 102 2 2 2 0 00-2-2zm0-1a3 3 0 11-3 3 3 3 0 013-3zm8 10a1 1 0 01-1 1H5a1 1 0 01-1-1zm1-13H3.05a1 1 0 00-1 1v10a1 1 0 001 1.05H21A1 1 0 0022 16V6.05A1 1 0 0021 5zM3 6.5a.5.5 0 01.5-.5h1.56A2.06 2.06 0 013 8.06zm.5 9.5a.5.5 0 01-.5-.5v-1.56A2.06 2.06 0 015.06 16zm17.5-.5a.5.5 0 01-.5.5h-1.56A2.06 2.06 0 0121 13.94zm0-2.56A3.06 3.06 0 0017.94 16H6.06A3.06 3.06 0 003 12.94V9.06A3.06 3.06 0 006.06 6h11.88A3.06 3.06 0 0021 9.06zm0-4.88h-.1a1.74 1.74 0 01-2-2.07h1.6a.5.5 0 01.5.5z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Salaries
#                </span>
#               </span>
#               <span class="SVGInline d-flex ml-sm mr-std icon__IconStyles__colorNavigation">
#                <svg class="SVGInline-svg d-flex-svg ml-sm-svg mr-std-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#             </div>
#            </li>
#            <li class="p-0 m-0">
#             <div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header careers" data-ga-lbl="null" data-test="site-header-careers" href="/Career/index.htm" rel="" tabindex="0" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M12 3a9 9 0 11-9 9 9 9 0 019-9m0-1a10 10 0 1010 10A10 10 0 0012 2z" fill="currentColor" fill-rule="evenodd">
#                </path>
#                <path d="M7.05 17l7.07-2.83L17 7.05 9.88 9.88zm3.4-5.8l2.4 2.4-4 1.6zm3.1 1.7l-2.4-2.4 4-1.6zM12 7a.5.5 0 00.5-.5v-2a.5.5 0 00-1 0v2a.5.5 0 00.5.5zm0 10a.5.5 0 00-.5.5v2a.5.5 0 001 0v-2a.5.5 0 00-.5-.5zm7.5-5.5h-2a.5.5 0 000 1h2a.5.5 0 000-1zm-13 0h-2a.5.5 0 000 1h2a.5.5 0 000-1z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Careers
#                </span>
#               </span>
#               <span class="SVGInline d-flex ml-sm mr-std icon__IconStyles__colorNavigation">
#                <svg class="SVGInline-svg d-flex-svg ml-sm-svg mr-std-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#             </div>
#            </li>
#           </ul>
#           <ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu pt-sm">
#            <li class="p-0 m-0">
#             <div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-track-cmpgn="Website - B2C | FEA2 | gdemployermenu" data-track-source="gdemployermenu" data-track-type="source" href="/employers/" rel="" tabindex="0" target="_top">
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 For Employers
#                </span>
#               </span>
#               <span class="SVGInline d-flex ml-sm mr-std icon__IconStyles__colorNavigation">
#                <svg class="SVGInline-svg d-flex-svg ml-sm-svg mr-std-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#              </div>
#             </div>
#            </li>
#            <li class="p-0 m-0">
#             <a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header for employers post a job" data-ga-lbl="post-a-job" data-track-cmpgn="home" data-track-source="mega-menu-locked-b2c" data-track-type="src" href="/post-job" rel="" target="">
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Post a Job
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation">
#          <div>
#           <div class="col">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader">
#             <div class="col">
#              <div class="d-flex flex-row">
#               <button aria-label="Go back in navigation menu" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Go back in navigation menu" type="button">
#                <span class="SVGInline d-flex icon__IconStyles__colorNavigation">
#                 <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#             <div>
#              <div class="d-flex flex-row">
#               <button aria-label="Close navigation menu" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" type="button">
#                <span class="SVGInline d-flex icon__IconStyles__colorNavigation">
#                 <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="col siteHeader__HeaderStyles__bottomShadow">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left">
#             <div class="d-flex">
#              <div class="siteHeader__HeaderStyles__h1">
#               Jobs
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto">
#           <ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu">
#            <li class="m-0 p-0">
#             <a class="d-flex align-items-center col pl-std ---------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header discover jobs" data-ga-lbl="Discover" href="/Job/index.htm" rel="" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <div class="d-flex align-items-center py-std col header-menu-item-label">
#               <span class="col">
#                <span class="menuItem__MenuItemStyles__menuItemColor">
#                 Discover Jobs
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation">
#          <div>
#           <div class="col">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader">
#             <div class="col">
#              <div class="d-flex flex-row">
#               <button aria-label="Go back in navigation menu" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Go back in navigation menu" type="button">
#                <span class="SVGInline d-flex icon__IconStyles__colorNavigation">
#                 <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#             <div>
#              <div class="d-flex flex-row">
#               <button aria-label="Close navigation menu" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" type="button">
#                <span class="SVGInline d-flex icon__IconStyles__colorNavigation">
#                 <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="col siteHeader__HeaderStyles__bottomShadow">
#            <div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left">
#             <div class="d-flex">
#              <div class="siteHeader__HeaderStyles__h1">
#               Companies
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto">
#           <ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu">
#            <li class="m-0 p-0">
#             <a class="d-flex align-items-center col pl-std --------------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-amplitude-lbl="site header discover companies" data-ga-lbl="Discover" href="/Reviews/index.htm" rel="" target="_top">
#              <span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm">
#               <svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
# ...
# window.GD.page.headerPageId = "explore";
# window.GD.page.footerData = {"introText":"","copyrightTextKey":"msg.footer.min.text","jsonString":"{\"mainMenu\":[{\"link\":\"\",\"textKey\":\"label.glassdoor\",\"childNavigationLinks\":[{\"link\":\"https://www.glassdoor.com/about/\",\"textKey\":\"link.label.aboutus.nolegal\",\"target\":\"_top\",\"amplitudeLabel\":\"site footer About press\"},{\"link\":\"https://www.glassdoor.com/blog/\",\"textKey\":\"link.label.gd-blog\",\"target\":\"_top\",\"amplitudeLabel\":\"site footer Blog\"},{\"link\":\"https://help.glassdoor.com/s/article/Grievance-Officer-India?language=en_US\",\"textKey\":\"link.label.grievanceOfficer.legal\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer Grievance Officer\"}]},{\"link\":\"\",\"textKey\":\"label.employers\",\"childNavigationLinks\":[{\"link\":\"https://www.glassdoor.co.in/employers/sign-up/?src=gdfoot\",\"textKey\":\"link.label.talent.solutions\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer Get a Free Employer Account\"},{\"link\":\"/partners/index.htm\",\"textKey\":\"link.label.employer.center\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer Employer Center\"},{\"link\":\"/post-job\",\"textKey\":\"link.label.post.job\",\"target\":\"_top\",\"tracking\":{\"SOURCE\":\"site-footer\"},\"amplitudeLabel\":\"site footer Post a job\"}]},{\"link\":\"\",\"textKey\":\"label.community\",\"childNavigationLinks\":[{\"link\":\"https://help.glassdoor.com\",\"textKey\":\"link.label.help-center\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer Help Contact us\"},{\"link\":\"https://help.glassdoor.com/article/Community-Guidelines/en_US\",\"textKey\":\"link.label.guidelines\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer guidelines\"},{\"link\":\"/about/terms.htm\",\"textKey\":\"link.label.terms.new\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer terms of use\"},{\"link\":\"https://hrtechprivacy.com/brands/glassdoor#privacypolicy\",\"textKey\":\"link.label.privacy.cookies.new\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer privacy cookies\"},{\"link\":\"https://hrtechprivacy.com/\",\"textKey\":\"link.label.privacy.center\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer privacy center\"},{\"link\":\"/about/doNotSell.htm\",\"textKey\":\"link.label.ccpa\",\"amplitudeLabel\":\"site footer do not sell\"},{\"link\":\"#\",\"id\":\"CookieConsentToolLink\",\"textKey\":\"link.label.cookieConsentTool\",\"amplitudeLabel\":\"site footer cookie consent tool\"}]},{\"link\":\"\",\"textKey\":\"label.work.with.us\",\"childNavigationLinks\":[{\"textKey\":\"link.label.advertisers\",\"rel\":\"nofollow\",\"target\":\"_blank\",\"link\":\"http://resources.glassdoor.com/advertising-on-glassdoor.html\",\"amplitudeLabel\":\"site footer advertisers\"},{\"link\":\"/Jobs/Glassdoor-Jobs-E100431.htm\",\"textKey\":\"link.label.careers\",\"target\":\"_top\",\"rel\":\"nofollow\",\"amplitudeLabel\":\"site footer careers\"}]}],\"socialMenu\":[{\"link\":\"/glassdoor\",\"textKey\":\"\",\"iconKey\":\"glassdoor\",\"target\":\"_top\",\"amplitudeLabel\":\"site footer Glassdoor homepage\"},{\"link\":\"https://www.facebook.com/Glassdoor/\",\"textKey\":\"\",\"iconKey\":\"facebook\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer facebook\"},{\"link\":\"https://twitter.com/Glassdoor\",\"textKey\":\"\",\"iconKey\":\"twitter\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer twitter\"},{\"link\":\"https://www.youtube.com/Glassdoor\",\"textKey\":\"\",\"iconKey\":\"youtube\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer youtube\"},{\"link\":\"https://www.instagram.com/glassdoor\",\"textKey\":\"\",\"iconKey\":\"instagram\",\"target\":\"_blank\",\"amplitudeLabel\":\"site footer instagram\"}],\"appMenu\":{\"link\":\"\",\"textKey\":\"footer.appstore-cta.download-text\",\"childNavigationLinks\":[{\"link\":\"https://play.google.com/store/apps/details?id=com.glassdoor.app&hl=en&referrer=utm_sour ...
# window.GD.page.isWebviewNative = undefined;
# window.GD.coreI18nTranslation = {"_":"","footer":{"msg.footer.text":"Glassdoor has millions of jobs plus salary information, company reviews, and interview questions from people on the inside making it easy to find a job that’s right for you.","msg.footer.min.text":"Copyright [copyright] 2008[dash][year], Glassdoor, Inc. \"Glassdoor\" and logo are registered trademarks of Glassdoor, Inc","msg.footer.blog-intro":"Glassdoor’s Blog provides valuable content to the conscious job seeker and employees who are passionate about furthering and deepening their careers.","label.glassdoor":"Glassdoor","label.employers":"Employers","label.community":"Community","label.work.with.us":"Work With Us","link.label.aboutus.nolegal":"About / Press","link.label.aboutus.alternative":"About Us","link.label.aboutus.legal":"About Us & Legal Notice","link.label.careers":"Careers","link.label.widgets":"Glassdoor Widgets","link.label.feedback":"Feedback","link.label.talent.solutions":"Get a FREE Employer Account","link.label.freeEmployerAccount":"Free Employer Account","link.label.employer.center":"Employer Centre","link.label.post.job":"Post a Job","link.label.help.faq":"Help / FAQ","link.label.help-center":"Help / Contact Us","link.label.guidelines":"Guidelines","link.label.privacy.cookies":"Privacy & Cookies","link.label.privacy.cookies.new":"Privacy & Cookies (New)","link.label.privacy.center":"Privacy Center","link.label.privacy.center.new":"Privacy Center (New)","link.label.ccpa":"Do Not Sell Or Share My Information","link.label.cookieConsentTool":"Cookie Consent Tool","link.label.privacy":"Privacy","link.label.terms":"Terms of Use","link.label.terms.new":"Terms of Use (New)","link.label.job.boards":"Job Boards","link.label.advertisers":"Advertisers","link.label.developers":"Developers","link.label.glassdoor.research":"Research","link.label.glassdoor.economicResearch":"Economic Research","link.label.glassdoor.aboutus":"About / Press","link.label.about.glassdoor":"About Glassdoor","link.label.executive":"Executive Team","link.label.events.conferences":"Events & Conferences","link.label.connect.with.us":"Connect with Us","link.label.employer.branding":"Employer Branding","link.label.employer.brand-solutions":"Employer Brand Solutions","link.label.employer.blog":"Employers Blog","link.label.recruit.engineers":"Recruit Engineers","link.label.retail.recruiting":"Retail Recruiting","link.label.innovation-lab":"Innovation Lab","link.label.sales":"Talk to Sales","link.help-center-domain":"https://help.glassdoor.com/GlassDoorHome/en_US","link.label.impressum.legal":"Imprint","link.label.grievanceOfficer.legal":"Grievance Officer - India","link.label.guides":"Guides","link.label.career-guides":"Career Guides","link.label.editorial-team":"Editorial Team","link.label.more-from-glassdoor":"More from Glassdoor","link.label.best-places-to-work":"Best Places to Work","link.label.top-ceos":"Top CEOs","link.label.fishbowl-by-glassdoor":"Fishbowl by Glassdoor","link.label.covid-resources":"COVID-19 Resources","link.label.land-the-right-job":"Land the Right Job","link.label.gender-pay-gap-breakdown":"The Gender Pay Gap Breakdown","footer.appstore-cta.download-text":"Download the App","footer.form.label.country":"Choose a Country","site.directory.salaries.by.job":"Salaries by Job","site.directory.salaries.by.company":"Salaries by Company","site.directory.salaries.by.city":"Salaries by City","site.directory.reviews.by.company":"Reviews by Company","site.directory.interview.questions.by.job":"Interview Questions by Job","site.directory.interviews.by.company":"Interviews by Company","site.directory.benefits.by.company":"Benefits by Company","site.directory.jobs.by.title":"Jobs by Title","site.directory.jobs.by.company":"Jobs by Company","site.directory.jobs.by.city":"Jobs by City","site.directory.jobs":"Jobs","site.directory.companies":"Companies","site.directory.locations":"Locations","site.directory.browseby":"Browse by: ","site.directory.signUp":"Sign up to become a mem ...
# window.GD.page.garnishManifest = {"403":{"js":"/garnish/static/js/gd-403.bundle.40a20.js"},"runtime":{"js":"/garnish/static/js/gd-runtime.bundle.d74e2.js"},"vendor":{"js":"/garnish/static/js/gd-vendor.bundle.6e316.js"},"12mgtg-thankyou-modal":{"js":"/garnish/static/js/gd-12mgtg-thankyou-modal.bundle.95ac1.js"},"alertMessage":{"js":"/garnish/static/js/gd-alertMessage.bundle.9a65c.js"},"core":{"css":"/garnish/static/css/gd-core.bundle.45ef8.css","js":"/garnish/static/js/gd-core.bundle.6472f.js"},"footer":{"css":"/garnish/static/css/gd-footer.bundle.f1857.css","js":"/garnish/static/js/gd-footer.bundle.63d1a.js"},"lockedHeader":{"css":"/garnish/static/css/gd-lockedHeader.bundle.0fdf4.css","js":"/garnish/static/js/gd-lockedHeader.bundle.1f229.js"},"minimalHeader":{"js":"/garnish/static/js/gd-minimalHeader.bundle.677f4.js"},"partnerCenterCore":{"css":"/garnish/static/css/gd-partnerCenterCore.bundle.f1532.css","js":"/garnish/static/js/gd-partnerCenterCore.bundle.3a6b7.js"},"partnerCenterFooter":{"css":"/garnish/static/css/gd-partnerCenterFooter.bundle.d5738.css","js":"/garnish/static/js/gd-partnerCenterFooter.bundle.76647.js"},"partnerCenterHeader":{"css":"/garnish/static/css/gd-partnerCenterHeader.bundle.79aca.css","js":"/garnish/static/js/gd-partnerCenterHeader.bundle.b15b7.js"},"siteHeader":{"css":"/garnish/static/css/gd-siteHeader.bundle.a3de5.css","js":"/garnish/static/js/gd-siteHeader.bundle.1a1e9.js"},"sw-register":{"js":"/garnish/static/js/gd-sw-register.bundle.f7f18.js"},"userAlert":{"js":"/garnish/static/js/gd-userAlert.bundle.3b936.js"},"job-alert-inline-v2":{"css":"/garnish/static/css/gd-job-alert-inline-v2.bundle.css?v=2249d","js":"/garnish/static/js/gd-job-alert-inline-v2.bundle.js?v=edb8a"},"job-alert-inline":{"css":"/garnish/static/css/gd-job-alert-inline.bundle.css?v=f9b81","js":"/garnish/static/js/gd-job-alert-inline.bundle.js?v=f4cbc"},"user-hardsell-overlay":{"css":"/garnish/static/css/gd-user-hardsell-overlay.bundle.css?v=475ff","js":"/garnish/static/js/gd-user-hardsell-overlay.bundle.js?v=4592d"},"user-hardsell":{"css":"/garnish/static/css/gd-user-hardsell.bundle.css?v=ebf2a","js":"/garnish/static/js/gd-user-hardsell.bundle.js?v=cabbc"},"user-login-all":{"css":"/garnish/static/css/gd-user-login-all.bundle.css?v=704ae","js":"/garnish/static/js/gd-user-login-all.bundle.js?v=441fc"},"user-login-fishbowl-co-reg":{"css":"/garnish/static/css/gd-user-login-fishbowl-co-reg.bundle.css?v=d4905","js":"/garnish/static/js/gd-user-login-fishbowl-co-reg.bundle.js?v=dad6d"},"user-login-l2a":{"css":"/garnish/static/css/gd-user-login-l2a.bundle.css?v=6b5e5","js":"/garnish/static/js/gd-user-login-l2a.bundle.js?v=32394"},"user-login-one-tap":{"css":"/garnish/static/css/gd-user-login-one-tap.bundle.css?v=26089","js":"/garnish/static/js/gd-user-login-one-tap.bundle.js?v=c0263"},"user-login-post-apply":{"css":"/garnish/static/css/gd-user-login-post-apply.bundle.css?v=d5283","js":"/garnish/static/js/gd-user-login-post-apply.bundle.js?v=0968c"},"user-login":{"css":"/garnish/static/css/gd-user-login.bundle.css?v=1571b","js":"/garnish/static/js/gd-user-login.bundle.js?v=2f26d"},"user-unvalidated":{"css":"/garnish/static/css/gd-user-unvalidated.bundle.css?v=a949d","js":"/garnish/static/js/gd-user-unvalidated.bundle.js?v=65c3b"},"bannerAppInstall":{"js":"/garnish/static/js/gd-bannerAppInstall.bundle.js?v=31908"},"brand-views-no-polyfill":{"js":"/garnish/static/js/gd-brand-views-no-polyfill.bundle.js?v=27d89"},"brand-views":{"js":"/garnish/static/js/gd-brand-views.bundle.js?v=355df"},"covid19Banner":{"js":"/garnish/static/js/gd-covid19Banner.bundle.js?v=ac40d"},"crunchbase-widget":{"js":"/garnish/static/js/gd-crunchbase-widget.bundle.js?v=0947b"},"display-ads":{"js":"/garnish/static/js/gd-display-ads.bundle.js?v=3fc1d"},"diversity-and-inclusion":{"js":"/garnish/static/js/gd-diversity-and-inclusion.bundle.js?v=75640"},"diversityAndInclusionBanner":{"js":"/garnish/static/js/gd-diversityAndInclusionBanner.bundle.js?v=0111c"},"ei-faq-overview-mo ...
# window.GD.page.alertMessageData = {};
#   </script>
#   <script nonce="">
#    window.addEventListener('load', function() {
#     if(new Date().getTime() - (sessionStorage['js-session-valid'] || 0) > 45 * 60 * 1000) {
#         sessionStorage['js-session-valid'] = new Date().getTime();
#         const req = new XMLHttpRequest();
#         req.open('POST', '/util/ajax/bwl.htm');
#         req.setRequestHeader('Content-Type', 'application/x-www-form-urlencoded');
#         req.send('guid=' + encodeURIComponent(getGdGlobals().page.guid) + '&gdToken=' + encodeURIComponent(GD.page.gdToken));
#     }
# });
#   </script>
#   <div>
#    <script defer="" src="/garnish/static/js/gd-alertMessage.bundle.9a65c.js">
#    </script>
#    <script defer="" src="/garnish/static/js/gd-footer.bundle.63d1a.js">
#    </script>
#    <script defer="" src="/garnish/static/js/gd-siteHeader.bundle.1a1e9.js">
#    </script>
#    <script defer="" src="/garnish/static/js/gd-userAlert.bundle.3b936.js">
#    </script>
#   </div>
#   <div>
#    <script defer="" src="/garnish/static/js/gd-user-login-one-tap.bundle.js?v=c0263">
#    </script>
#   </div>
#   <script defer="" src="/explore/static/js/gd-vendor.bundle.55acb.js" type="text/javascript">
#   </script>
#   <script defer="" src="/explore/static/js/gd-companyExplorer.bundle.55acb.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
title=soup.title
print(title)
# Out:
# <title data-rh="true">Browse Companies | Glassdoor</title>

# %% [markdown]
# ## TO FIND OUT NAMES OF THE COMPANIES

# %%
soup.find_all('h2')
# Out:
# [<h2>Filter Companies</h2>,
#  <h2 data-test="employer-short-name">Tata Consultancy Services</h2>,
#  <h2 data-test="employer-short-name">Accenture</h2>,
#  <h2 data-test="employer-short-name">Amazon</h2>,
#  <h2 data-test="employer-short-name">Cognizant Technology Solutions</h2>,
#  <h2 data-test="employer-short-name">Deloitte</h2>,
#  <h2 data-test="employer-short-name">IBM</h2>,
#  <h2 data-test="employer-short-name">Capgemini</h2>,
#  <h2 data-test="employer-short-name">Wipro</h2>,
#  <h2 data-test="employer-short-name">EY</h2>,
#  <h2 data-test="employer-short-name">HCLTech</h2>]

# %%
for i in soup.find_all('h2')[1:]:
    print(i.text.strip())
# Out:
# Tata Consultancy Services
# Accenture
# Amazon
# Cognizant Technology Solutions
# Deloitte
# IBM
# Capgemini
# Wipro
# EY
# HCLTech

# %% [markdown]
# ## TO FIND OUT COMPANY DETAILS

# %%
for i in soup.find_all('div',class_='row d-flex flex-wrap'):
    print(i.text.strip())
# Out:
# Tata Consultancy Services3.9★1.2LReviews1.2LSalaries658JobsLocation39 office locationsGlobal Company Size10000+ EmployeesIndustrySoftware Development
# Accenture4.1★1.5LReviews75.1TSalaries22.9TJobsLocation37 office locationsGlobal Company Size10000+ EmployeesIndustryBusiness ConsultingDescriptionGrowing customer expectations. Market-Shaping AI. Self-Optimizing systems. The post-digital age shows no signs of slow down, and the need for the new ideas powered by intelligent technologies has never been greater.
#
# A vision for the future can’t be realized without know-how. Accenture partners with our clients drive real innovation – the kind that turns an idea into an industry – helping them transform and grow their organizations. Learn how we work with companies from all industries across the globe to create the New, now.
# Amazon4.1★1.7LReviews40.8TSalaries10.9TJobsLocation65 office locationsGlobal Company Size10000+ EmployeesIndustryInternet & Web ServicesDescriptionAll Amazon teams and businesses, from Prime delivery to AWS, are guided by four key tenets: customer obsession rather than competitor focus, passion for invention, commitment to operational excellence, and long-term thinking.
#
# We are driven by the excitement of building technologies, inventing products, and providing services that transform the way our customers live their lives and run their businesses.
# Cognizant Technology Solutions3.9★84.7TReviews69.8TSalaries4TJobsLocation27 office locationsGlobal Company Size10000+ EmployeesIndustryInformation Technology Support ServicesDescriptionCognizant is one of the world’s leading professional services companies, helping clients become data-enabled and data-driven in the digital era. Our industry-based, consultative approach helps companies evolve into modern businesses. By leading clients in leveraging technologies essential to modern enterprises such as IoT, artificial intelligence, digital engineering and cloud, we enable new business and operating models that unlock new value in markets around the world. Cognizant’s unwavering focus on our clients is led by over 330,000 associates, who deliver services and solutions tailored to specific industries and the unique needs of the organizations we serve.
# Deloitte4.1★97.6TReviews32.3TSalaries40.6TJobsLocation33 office locationsGlobal Company Size10000+ EmployeesIndustryAccounting & TaxDescriptionDeloitte provides industry-leading audit and assurance, tax and legal, consulting, financial advisory, and risk advisory services to nearly 90% of the Fortune Global 500® and thousands of private companies. Our more than 345,000 professionals deliver measurable and lasting results that help reinforce public trust in capital markets, enable clients to transform and thrive, and lead the way toward a stronger economy, a more equitable society and a sustainable world. Building on its 175-plus year history, Deloitte spans more than 150 countries and territories.
#
# Deloitte US-India offices is part of region within the Deloitte US organization, with offices across four cities in India — Hyderabad, Mumbai, Delhi, and Bengaluru.
# IBM4.2★1LReviews32TSalaries4.6TJobsLocation37 office locationsGlobal Company Size10000+ EmployeesIndustryInformation Technology Support ServicesDescriptionIBM works to design, advance, and scale the technologies that define each era. Restlessly reinventing since 1911, we are one of the largest technology, consulting and research companies in the world.  IBMers are agents of change – in this team, you’ll become a part of a historic, prestigious, and global community in which you’ll be respected, and your talents will have a real impact.
#
# Join our team of experts and thrive in a collaborative and friendly environment where you can bring your whole self at work. Use your skills to empower clients and partners to create something that is bigger than what any one of us could produce alone.
#
# Come and let’s create together!
# Capgemini4.0★68.5TReviews44.8TSalaries9.3TJobsLocation54 office locationsGlobal Company Size10000+ EmployeesIndustryEnterprise Software & Network SolutionsDescriptionCapgemini is a global leader in partnering with companies to transform and manage their business by harnessing the power of technology. The Group is guided everyday by its purpose of unleashing human energy through technology for an inclusive and sustainable future. It is a responsible and diverse organization of 360,000 team members in more than 50 countries. With its strong 55-year heritage and deep industry expertise, Capgemini is trusted by its clients to address the entire breadth of their business needs, from strategy and design to operations, fueled by the fast evolving and innovative world of cloud, data, AI, connectivity, software, digital engineering and platforms. The Group reported in 2022 global revenues of €22 billion.
# Get The Future You Want | www.capgemini.com
#
# Capgemini in India comprises over 185,000 team members working across 13 locations: Bangalore, Bhubaneswar, Chennai, Coimbatore, Gandhinagar, Gurugram, Hyderabad, Kolkata, Mumbai, Noida, Pune, Salem and Tiruchirappalli. Learn more about Capgemini in India at www.capgemini.com/in-en.
# Wipro3.8★53.1TReviews45.3TSalaries1.4TJobsLocation38 office locationsGlobal Company Size10000+ EmployeesIndustryInformation Technology Support ServicesDescriptionWipro Limited (NYSE: WIT, BSE: 507685, NSE: WIPRO) is a leading technology services and consulting firm focused on building innovative solutions that address clients’ most complex digital transformation needs.
#
# Leveraging our holistic portfolio of capabilities in consulting, design, engineering, and operations, we help clients realize their boldest ambitions and build future-ready, sustainable businesses. With over 250,000 employees and business partners across 66 countries, we deliver on the promise of helping our customers, colleagues, and communities, to thrive in an ever-changing world.
# EY3.9★70.1TReviews18.3TSalaries13.5TJobsLocation5 office locationsGlobal Company Size10000+ EmployeesIndustryAccounting & TaxDescriptionEY is a global leader in assurance, tax, transaction and advisory services. The insights and quality services we deliver help build trust and confidence in the capital markets and in economies the world over. We develop outstanding leaders who team to deliver on our promises to all of our stakeholders. In so doing, we play a critical role in building a better working world for our people, for our clients and for our communities.
#
# EY refers to the global organization and may refer to one or more of the member firms of Ernst & Young Global Limited, each of which is a separate legal entity. Ernst & Young Global Limited, a UK company limited by guarantee, does not provide services to clients. For more information about our organization, please visit ey.com.
# HCLTech3.7★39.9TReviews32.3TSalaries891JobsLocation26 office locationsGlobal Company Size10000+ EmployeesIndustryComputer Hardware DevelopmentDescriptionHCLTech is a global technology company, home to 225,900+ people across 60 countries, delivering industry-leading capabilities centered around digital, engineering and cloud powered by a broad portfolio of technology services and products. We work with clients across all major verticals, providing industry solutions for Financial Services, Manufacturing, Life Sciences and Healthcare, Technology and Services, Telecom and Media, Retail and CPG, and Public Services.
#
# Our purpose is to bring together the best of technology and our people to supercharge progress. We’re supercharging progress for everyone, everywhere – our clients, partners and their stakeholders, our people, communities, and the planet.
#
# Part of the HCL group, HCLTech was listed on the stock exchanges in India at the turn of the millennium in December 1999. Since our inception, we have pioneered several industry mainstays and established leadership positions in all our chosen segments.
#
# As a company, we are deeply focused on accelerating our ESG agenda. We are also creating technology-enabled sustainable solutions with and for our clients and partners. We embed ESG imperatives into every aspect of our business and ensure that the progress we supercharge is responsible, inclusive and beneficial to all our stakeholders in the long term. We have committed to achieving net zero by 2040.
#
# We recognize the impact that a business like ours can deliver in elevating communities globally, and we continue to improve our efforts and take decisive actions that benefit the communities in which we work and live. Through the HCL Foundation, the CSR arm of HCLTech, we have invested more than $130 million in social development efforts serving communities throughout India across education, health, water, sanitation and hygiene, skill development and livelihoods, environment, and disaster risk reduction, response and management.
#
# We’re powered by our people – a global, diverse, multi-generational talent - representing 161 nationalities whose unique spark, perspective and boundless passion drive our culture of proactive value creation and problem-solving.
#
# Consolidated revenues as of 12 months ending March 2023 totaled $12.6 billion. To learn how we can supercharge progress for you, visit hcltech.com

# %%
len(soup.find_all('b'))
# Out:
# 56

# %%
len(soup.find_all('div' , class_='d-flex flex-column align-items-center'))
# Out:
# 30

# %% [markdown]
# ## CONSIDERING THE WHOLE CONTAINER

# %%
company=soup.find_all('div',class_='row d-flex flex-wrap')

# %%
len(company)
# Out:
# 10

# %% [markdown]
# ## COMPANY DESCRIPTION

# %%
comp_detail=soup.find('p',class_='css-1sj9xzx css-56kyx5').text.strip()[:215]
print(comp_detail)
# Out:
# Growing customer expectations. Market-Shaping AI. Self-Optimizing systems. The post-digital age shows no signs of slow down, and the need for the new ideas powered by intelligent technologies has never been greater.

# %%
c_name=[]
rating=[]
reviews=[]
industry=[]
hq=[]
jobs=[]
employee=[]




for i in company:
   c_name.append(i.find('h2').text.strip())
   rating.append(i.find('b').text.strip())
   reviews.append(i.find('div' , class_='d-flex flex-column align-items-center').text.strip())
   industry.append(i.find('span', attrs = {'data-test' : 'employer-industry'}).text.strip())
   hq.append(i.find('span',class_='d-block mt-0 css-56kyx5').text.strip())
   jobs.append(i.find('h3', attrs = {'data-test' : 'cell-Jobs-count'}).text.strip())
   employee.append(i.find('span', attrs = {'data-test' : 'employer-size'}).text.strip())
 
  
df=pd.DataFrame({'Company_name':c_name,'Rating':rating,'Reviews':reviews,'Industry_type':industry,'Total_headquater':hq,'Total_jobs':jobs,'Total_employee':employee,
                })

# %% [markdown]
# ## COMPANY NAMES

# %%
c_name
# Out:
# ['Tata Consultancy Services',
#  'Accenture',
#  'Amazon',
#  'Cognizant Technology Solutions',
#  'Deloitte',
#  'IBM',
#  'Capgemini',
#  'Wipro',
#  'EY',
#  'HCLTech']

# %% [markdown]
# ## COMPANY RATINGS

# %%
rating
# Out:
# ['3.9', '4.1', '4.1', '3.9', '4.1', '4.2', '4.0', '3.8', '3.9', '3.7']

# %% [markdown]
# ## COMPANY REVIEWS

# %%
reviews
# Out:
# ['1.2LReviews',
#  '1.5LReviews',
#  '1.7LReviews',
#  '84.7TReviews',
#  '97.6TReviews',
#  '1LReviews',
#  '68.5TReviews',
#  '53.1TReviews',
#  '70.1TReviews',
#  '39.9TReviews']

# %% [markdown]
# ## INDUSTRY TYPES

# %%
industry
# Out:
# ['Software Development',
#  'Business Consulting',
#  'Internet & Web Services',
#  'Information Technology Support Services',
#  'Accounting & Tax',
#  'Information Technology Support Services',
#  'Enterprise Software & Network Solutions',
#  'Information Technology Support Services',
#  'Accounting & Tax',
#  'Computer Hardware Development']

# %% [markdown]
# ## TOTAL NUMBER OF COMPANIES LOCATION

# %%
hq
# Out:
# ['39 office locations',
#  '37 office locations',
#  '65 office locations',
#  '27 office locations',
#  '33 office locations',
#  '37 office locations',
#  '54 office locations',
#  '38 office locations',
#  '5 office locations',
#  '26 office locations']

# %% [markdown]
# ## TOTAL JOBS

# %%
jobs
# Out:
# ['658',
#  '22.9T',
#  '10.9T',
#  '4T',
#  '40.6T',
#  '4.6T',
#  '9.3T',
#  '1.4T',
#  '13.5T',
#  '891']

# %% [markdown]
# ## TOTAL EMPLOYEE

# %%
employee
# Out:
# ['10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees',
#  '10000+ Employees']

# %% [markdown]
# ## DATAFRAME

# %%
df
# Out:
#                      Company_name Rating       Reviews  \
# 0       Tata Consultancy Services    3.9   1.2LReviews
# 1                       Accenture    4.1   1.5LReviews
# 2                          Amazon    4.1   1.7LReviews
# 3  Cognizant Technology Solutions    3.9  84.7TReviews
# 4                        Deloitte    4.1  97.6TReviews
# 5                             IBM    4.2     1LReviews
# 6                       Capgemini    4.0  68.5TReviews
# 7                           Wipro    3.8  53.1TReviews
# 8                              EY    3.9  70.1TReviews
# 9                         HCLTech    3.7  39.9TReviews
#
#                              Industry_type     Total_headquater Total_jobs  \
# 0                     Software Development  39 office locations        658
# 1                      Business Consulting  37 office locations      22.9T
# 2                  Internet & Web Services  65 office locations      10.9T
# 3  Information Technology Support Services  27 office locations         4T
# 4                         Accounting & Tax  33 office locations      40.6T
# 5  Information Technology Support Services  37 office locations       4.6T
# 6  Enterprise Software & Network Solutions  54 office locations       9.3T
# 7  Information Technology Support Services  38 office locations       1.4T
# 8                         Accounting & Tax   5 office locations      13.5T
# 9            Computer Hardware Development  26 office locations        891
#
#      Total_employee
# 0  10000+ Employees
# 1  10000+ Employees
# 2  10000+ Employees
# 3  10000+ Employees
# 4  10000+ Employees
# 5  10000+ Employees
# 6  10000+ Employees
# 7  10000+ Employees
# 8  10000+ Employees
# 9  10000+ Employees

# %%
df.shape
# Out:
# (10, 7)

# %% [markdown]
# ## CREATING DATAFRAME FOR ALL PAGES

# %%
final=df

for j in range (1,11):

     url='https://www.glassdoor.co.in/Explore/browse-companies.htm?page={}'.format(j)
     headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
     webpage=requests.get(url,headers=headers).text
     soup=BeautifulSoup(webpage, 'lxml')
     company=soup.find_all('div',class_='row d-flex flex-wrap')

     c_name=[]
     rating=[]
     reviews=[]
     industry=[]
     hq=[]
     jobs=[]
     employee=[]

     for i in company:
        try:
          c_name.append(i.find('h2').text.strip())
        except:
          c_name.append(np.nan)   

        try:
           rating.append(i.find('b').text.strip())
        except:
            rating.append(np.nan)   

        try:
          reviews.append(i.find('div' , class_='d-flex flex-column align-items-center').text.strip())
        except:
           reviews.append(np.nan)  
 
        try:
          industry.append(i.find('span', attrs = {'data-test' : 'employer-industry'}).text.strip())
        except:
          industry.append(np.nan)   
      
        try:
           hq.append(i.find('span',class_='d-block mt-0 css-56kyx5').text.strip())
        except:
           hq.append(np.nan)  

        try:
          jobs.append(i.find('h3', attrs = {'data-test' : 'cell-Jobs-count'}).text.strip())
        except:
          jobs.append(np.nan)

        try:
           employee.append(i.find('span', attrs = {'data-test' : 'employer-size'}).text.strip())
        except:
           employee.append(np.nan)

  
     df=pd.DataFrame({  'Company_name':c_name,
                        'Rating':rating,
                        'Reviews':reviews,
                        'Industry_type':industry,
                        'Total_headquater':hq,
                        'Total_jobs':jobs,
                        'Total_employee':employee,
                      }) 
     final=final.append(df)

# %%
final
# Out:
#                       Company_name Rating       Reviews  \
# 0        Tata Consultancy Services    3.9   1.2LReviews
# 1                        Accenture    4.1   1.5LReviews
# 2                           Amazon    4.1   1.7LReviews
# 3   Cognizant Technology Solutions    3.9  84.7TReviews
# 4                         Deloitte    4.1  97.6TReviews
# ..                             ...    ...           ...
# 5                              UBS    4.0    13TReviews
# 6                              Jio    3.8   5.3TReviews
# 7                         Flipkart    4.0   4.8TReviews
# 8                             AT&T    3.7  38.5TReviews
# 9                      GlobalLogic    4.0   6.1TReviews
#
#                               Industry_type     Total_headquater Total_jobs  \
# 0                      Software Development  39 office locations        658
# 1                       Business Consulting  37 office locations      22.9T
# 2                   Internet & Web Services  65 office locations      10.9T
# 3   Information Technology Support Services  27 office locations         4T
# 4                          Accounting & Tax  33 office locations      40.6T
# ..                                      ...                  ...        ...
# 5             Investment & Asset Management  19 office locations       1.2T
# 6     Cable, Internet & Telephone Providers  25 office locations         65
# 7                   Internet & Web Services  10 office locations        128
# 8               Telecommunications Services  25 office locations       2.8T
# 9   Information Technology Support Services  40 office locations        973
#
#              Total_employee
# 0          10000+ Employees
# 1          10000+ Employees
# 2          10000+ Employees
# 3          10000+ Employees
# 4          10000+ Employees
# ..                      ...
# 5          10000+ Employees
# 6   5001 to 10000 Employees
# 7          10000+ Employees
# 8          10000+ Employees
# 9          10000+ Employees
#
# [110 rows x 7 columns]

# %%
final.shape
# Out:
# (110, 8)

# %%
df.sample(5)
# Out:
#   Company_name Rating       Reviews                   Industry_type  \
# 5          UBS    4.0    13TReviews   Investment & Asset Management
# 3     Unilever    4.1  14.6TReviews  Consumer Product Manufacturing
# 7     Flipkart    4.0   4.8TReviews         Internet & Web Services
# 4  BNP Paribas    3.8  13.1TReviews               Banking & Lending
# 8         AT&T    3.7  38.5TReviews     Telecommunications Services
#
#       Total_headquater Total_jobs    Total_employee
# 5  19 office locations       1.2T  10000+ Employees
# 3  25 office locations       1.5T  10000+ Employees
# 7  10 office locations        128  10000+ Employees
# 4  26 office locations       5.8T  10000+ Employees
# 8  25 office locations       2.8T  10000+ Employees

# %% [markdown]
# ## EXPOTING THE DATAFRAME INTO AN EXTENAL CSV

# %%
x = np.arange(len(final))
final.insert(0, 'index', x)
final.to_csv('final.csv',index=False)
